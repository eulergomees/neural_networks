# %% [markdown]
# # Atividade: Perceptron Multi Camadas XOR
# **INSTITUTO FEDERAL DE MINAS GERIAS**
# *Departamento de Engenharia e Computação*
#
# **Professor:** Ciniro Nametala
#
# **Aluno:** Euler Gomes

# %%
#importando bibliotecas
import numpy as np
import matplotlib.pyplot as plt
import cupy as cp

# %%
#secante hiperbolica ao quadrado (inversa da tangente hiperbolica)
def sech2(u):
    return 1 / np.cosh(u)**2

# %%
#dataset
x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[-1,1],[1,-1],[1,-1],[-1,1]])

# %%
#criar o bias
i1 = 1
i4 = 1
i5 = 1
i8 = 1

# %%
#inicialização dos pesos das matrizes Wji
w61 = np.random.uniform() - 0.5
w62 = np.random.uniform() - 0.5
w63 = np.random.uniform() - 0.5
w72 = np.random.uniform() - 0.5
w73 = np.random.uniform() - 0.5
w74 = np.random.uniform() - 0.5
w95 = np.random.uniform() - 0.5
w96 = np.random.uniform() - 0.5
w97 = np.random.uniform() - 0.5
w106 = np.random.uniform() - 0.5
w107 = np.random.uniform() - 0.5
w108 = np.random.uniform() - 0.5

# %%
#efinicao de parametros
contador_epocas = 0
tol = 0
erro_epoca_atual = tol + 1
n_amostras = 4

max_epocas = 10000
eta = 0.01
erro_epocas = np.zeros(max_epocas)

# %%
#treinamento da rede
while (contador_epocas < max_epocas) and (erro_epoca_atual < max_epocas):
    #exibe contador de epocas
    if contador_epocas % 10 == 0:
        print(f'epoca {contador_epocas}')

    #reseta o erro acumulado da epoca
    erro = 0

    #embaralha indices para apresentacao aleatoria das amostrar
    indices_embaralhados = np.random.permutation(n_amostras)

    for i in range(n_amostras):
        #seleciona um indice
        indices_selecionado = indices_embaralhados[i]

        #obter o conjunto de entrada x e sua respectiva saida y
        xi = x[indices_selecionado]
        yi = y[indices_selecionado]

        #separa componentes da entrada
        i2 = xi[0]
        i3 = xi[1]

        #separa componentes da saida
        y9 = yi[0]
        y10 = yi[1]

        #fase forward
        #calcula ativacao do neuronio 1 da camada
        u6 = i1 * w61 + i2 * w62 + i3 * w63
        i6 = np.tanh(u6)

        #calcula ativacao do neuronio 2 da camada 1
        u7 = i2 * w72 + i3 * w73 + i4 *w74
        i7 = np.tanh(u7)

        #calcula ativacao do neuronio 1 da camada 2
        u9 = i5 * w95 + i6 * w96 + i7 * w97
        i9 = np.tanh(u9)

        #calcula ativacao do neuronio 2 da camada 2
        u10 = i8 * w108 + i7 *w107 + i6 * w106
        i10 = np.tanh(u10)

        #fase backpropagation
        e9 = y9 - i9
        e10 = y10 - i10

        #atualizacao de pesos da camada 2
        #neuronio 1 da camada 2
        #pesos ligados ao neronio 1 da camada 2
        #calcula o gradiente do neuronio 1 da camada 2
        deltinha9 = e9*sech2(u9)

        #calcula ajustes dos pesos do neuronio 1 da camada 2
        deltaw95 = eta * deltinha9 * i5
        deltaw96 = eta * deltinha9 * i6
        deltaw97 = eta * deltinha9 * i7

        #atualizacao dos pesos do neuronio 1 da camada 2
        w95 = w95 + deltaw95
        w96 = w96 + deltaw96
        w97 = w97 + deltaw97

        #neuronio 2 da camada 2
        #pesos ligados ao neuronio 2 da camada 2
        #calcula o gradiente do neuronio 2 da camada 2
        deltinha10 = e10*sech2(u10)

        #calcula o ajustes dos pesos do neuronio 2 da camada 2
        deltaw106 = eta * deltinha10 * i6
        deltaw107 = eta * deltinha10 * i7
        deltaw108 = eta * deltinha10 * i8

        #atualizacao dos pesos ligados ao neuronio 2 da camada 2
        w106 = w106 + deltaw106
        w107 = w107 + deltaw107
        w108 = w108 + deltaw108

        #neuronio 1 da camada 1
        #pesos ligados ao neuronio 1 da camada 1
        #calcula o gradiente do neuronio 1 da camada 1
        deltinha6 = sech2(u6) * (deltinha9 * w96) * (deltinha10 * w106)

        #calcula ajustes dos pesos do neuronio 1 da camada 1
        deltaw61 = eta * deltinha6 * i1
        deltaw62 = eta * deltinha6 * i2
        deltaw63 = eta * deltinha6 * i3

        #atualiza os pesos do neuronio 1 da camada 1
        w61 = w61 + deltaw61
        w62 = w62 + deltaw62
        w63 = w63 + deltaw63

        #neuronio 2 da camada 1
        #pesos ligados ao neuronio 2 da camada 1
        #calcula o gradiente do neuronio 2 da camada 1
        deltinha7 = sech2(u7) * (deltinha9 * w97) * (deltinha10 * w107)

        #calcula ajustes dos pesos do neuronio 2 da camada 1
        deltaw72 = eta * deltinha7 * i2
        deltaw73 = eta * deltinha7 * i3
        deltaw74 = eta * deltinha7 * i4

        #atualiza os pesos do neuronio 2 da camada 1
        w72 = w72 + deltaw72
        w73 = w73 + deltaw73
        w74 = w74 + deltaw74

        #calcula o erro acumulado
        erro = erro + (np.pow(e9,2) + np.pow(e10, 2))

     #calcula o erro medio da epoca
    erro_epoca_atual = erro / n_amostras

    #armazena no historico de erros
    erro_epocas[contador_epocas] = erro_epoca_atual

    #incrmenta o contados de epocas
    contador_epocas = contador_epocas + 1
# Out:
# epoca 0
# epoca 10
# epoca 20
# epoca 30
# epoca 40
# epoca 50
# epoca 60
# epoca 70
# epoca 80
# epoca 90
# epoca 100
# epoca 110
# epoca 120
# epoca 130
# epoca 140
# epoca 150
# epoca 160
# epoca 170
# epoca 180
# epoca 190
# epoca 200
# epoca 210
# epoca 220
# epoca 230
# epoca 240
# epoca 250
# epoca 260
# epoca 270
# epoca 280
# epoca 290
# epoca 300
# epoca 310
# epoca 320
# epoca 330
# epoca 340
# epoca 350
# epoca 360
# epoca 370
# epoca 380
# epoca 390
# epoca 400
# epoca 410
# epoca 420
# epoca 430
# epoca 440
# epoca 450
# epoca 460
# epoca 470
# epoca 480
# epoca 490
# epoca 500
# epoca 510
# epoca 520
# epoca 530
# epoca 540
# epoca 550
# epoca 560
# epoca 570
# epoca 580
# epoca 590
# epoca 600
# epoca 610
# epoca 620
# epoca 630
# epoca 640
# epoca 650
# epoca 660
# epoca 670
# epoca 680
# epoca 690
# epoca 700
# epoca 710
# epoca 720
# epoca 730
# epoca 740
# epoca 750
# epoca 760
# epoca 770
# epoca 780
# epoca 790
# epoca 800
# epoca 810
# epoca 820
# epoca 830
# epoca 840
# epoca 850
# epoca 860
# epoca 870
# epoca 880
# epoca 890
# epoca 900
# epoca 910
# epoca 920
# epoca 930
# epoca 940
# epoca 950
# epoca 960
# epoca 970
# epoca 980
# epoca 990
# epoca 1000
# epoca 1010
# epoca 1020
# epoca 1030
# epoca 1040
# epoca 1050
# epoca 1060
# epoca 1070
# epoca 1080
# epoca 1090
# epoca 1100
# epoca 1110
# epoca 1120
# epoca 1130
# epoca 1140
# epoca 1150
# epoca 1160
# epoca 1170
# epoca 1180
# epoca 1190
# epoca 1200
# epoca 1210
# epoca 1220
# epoca 1230
# epoca 1240
# epoca 1250
# epoca 1260
# epoca 1270
# epoca 1280
# epoca 1290
# epoca 1300
# epoca 1310
# epoca 1320
# epoca 1330
# epoca 1340
# epoca 1350
# epoca 1360
# epoca 1370
# epoca 1380
# epoca 1390
# epoca 1400
# epoca 1410
# epoca 1420
# epoca 1430
# epoca 1440
# epoca 1450
# epoca 1460
# epoca 1470
# epoca 1480
# epoca 1490
# epoca 1500
# epoca 1510
# epoca 1520
# epoca 1530
# epoca 1540
# epoca 1550
# epoca 1560
# epoca 1570
# epoca 1580
# epoca 1590
# epoca 1600
# epoca 1610
# epoca 1620
# epoca 1630
# epoca 1640
# epoca 1650
# epoca 1660
# epoca 1670
# epoca 1680
# epoca 1690
# epoca 1700
# epoca 1710
# epoca 1720
# epoca 1730
# epoca 1740
# epoca 1750
# epoca 1760
# epoca 1770
# epoca 1780
# epoca 1790
# epoca 1800
# epoca 1810
# epoca 1820
# epoca 1830
# epoca 1840
# epoca 1850
# epoca 1860
# epoca 1870
# epoca 1880
# epoca 1890
# epoca 1900
# epoca 1910
# epoca 1920
# epoca 1930
# epoca 1940
# epoca 1950
# epoca 1960
# epoca 1970
# epoca 1980
# epoca 1990
# epoca 2000
# epoca 2010
# epoca 2020
# epoca 2030
# epoca 2040
# epoca 2050
# epoca 2060
# epoca 2070
# epoca 2080
# epoca 2090
# epoca 2100
# epoca 2110
# epoca 2120
# epoca 2130
# epoca 2140
# epoca 2150
# epoca 2160
# epoca 2170
# epoca 2180
# epoca 2190
# epoca 2200
# epoca 2210
# epoca 2220
# epoca 2230
# epoca 2240
# epoca 2250
# epoca 2260
# epoca 2270
# epoca 2280
# epoca 2290
# epoca 2300
# epoca 2310
# epoca 2320
# epoca 2330
# epoca 2340
# epoca 2350
# epoca 2360
# epoca 2370
# epoca 2380
# epoca 2390
# epoca 2400
# epoca 2410
# epoca 2420
# epoca 2430
# epoca 2440
# epoca 2450
# epoca 2460
# epoca 2470
# epoca 2480
# epoca 2490
# epoca 2500
# epoca 2510
# epoca 2520
# epoca 2530
# epoca 2540
# epoca 2550
# epoca 2560
# epoca 2570
# epoca 2580
# epoca 2590
# epoca 2600
# epoca 2610
# epoca 2620
# epoca 2630
# epoca 2640
# epoca 2650
# epoca 2660
# epoca 2670
# epoca 2680
# epoca 2690
# epoca 2700
# epoca 2710
# epoca 2720
# epoca 2730
# epoca 2740
# epoca 2750
# epoca 2760
# epoca 2770
# epoca 2780
# epoca 2790
# epoca 2800
# epoca 2810
# epoca 2820
# epoca 2830
# epoca 2840
# epoca 2850
# epoca 2860
# epoca 2870
# epoca 2880
# epoca 2890
# epoca 2900
# epoca 2910
# epoca 2920
# epoca 2930
# epoca 2940
# epoca 2950
# epoca 2960
# epoca 2970
# epoca 2980
# epoca 2990
# epoca 3000
# epoca 3010
# epoca 3020
# epoca 3030
# epoca 3040
# epoca 3050
# epoca 3060
# epoca 3070
# epoca 3080
# epoca 3090
# epoca 3100
# epoca 3110
# epoca 3120
# epoca 3130
# epoca 3140
# epoca 3150
# epoca 3160
# epoca 3170
# epoca 3180
# epoca 3190
# epoca 3200
# epoca 3210
# epoca 3220
# epoca 3230
# epoca 3240
# epoca 3250
# epoca 3260
# epoca 3270
# epoca 3280
# epoca 3290
# epoca 3300
# epoca 3310
# epoca 3320
# epoca 3330
# epoca 3340
# epoca 3350
# epoca 3360
# epoca 3370
# epoca 3380
# epoca 3390
# epoca 3400
# epoca 3410
# epoca 3420
# epoca 3430
# epoca 3440
# epoca 3450
# epoca 3460
# epoca 3470
# epoca 3480
# epoca 3490
# epoca 3500
# epoca 3510
# epoca 3520
# epoca 3530
# epoca 3540
# epoca 3550
# epoca 3560
# epoca 3570
# epoca 3580
# epoca 3590
# epoca 3600
# epoca 3610
# epoca 3620
# epoca 3630
# epoca 3640
# epoca 3650
# epoca 3660
# epoca 3670
# epoca 3680
# epoca 3690
# epoca 3700
# epoca 3710
# epoca 3720
# epoca 3730
# epoca 3740
# epoca 3750
# epoca 3760
# epoca 3770
# epoca 3780
# epoca 3790
# epoca 3800
# epoca 3810
# epoca 3820
# epoca 3830
# epoca 3840
# epoca 3850
# epoca 3860
# epoca 3870
# epoca 3880
# epoca 3890
# epoca 3900
# epoca 3910
# epoca 3920
# epoca 3930
# epoca 3940
# epoca 3950
# epoca 3960
# epoca 3970
# epoca 3980
# epoca 3990
# epoca 4000
# epoca 4010
# epoca 4020
# epoca 4030
# epoca 4040
# epoca 4050
# epoca 4060
# epoca 4070
# epoca 4080
# epoca 4090
# epoca 4100
# epoca 4110
# epoca 4120
# epoca 4130
# epoca 4140
# epoca 4150
# epoca 4160
# epoca 4170
# epoca 4180
# epoca 4190
# epoca 4200
# epoca 4210
# epoca 4220
# epoca 4230
# epoca 4240
# epoca 4250
# epoca 4260
# epoca 4270
# epoca 4280
# epoca 4290
# epoca 4300
# epoca 4310
# epoca 4320
# epoca 4330
# epoca 4340
# epoca 4350
# epoca 4360
# epoca 4370
# epoca 4380
# epoca 4390
# epoca 4400
# epoca 4410
# epoca 4420
# epoca 4430
# epoca 4440
# epoca 4450
# epoca 4460
# epoca 4470
# epoca 4480
# epoca 4490
# epoca 4500
# epoca 4510
# epoca 4520
# epoca 4530
# epoca 4540
# epoca 4550
# epoca 4560
# epoca 4570
# epoca 4580
# epoca 4590
# epoca 4600
# epoca 4610
# epoca 4620
# epoca 4630
# epoca 4640
# epoca 4650
# epoca 4660
# epoca 4670
# epoca 4680
# epoca 4690
# epoca 4700
# epoca 4710
# epoca 4720
# epoca 4730
# epoca 4740
# epoca 4750
# epoca 4760
# epoca 4770
# epoca 4780
# epoca 4790
# epoca 4800
# epoca 4810
# epoca 4820
# epoca 4830
# epoca 4840
# epoca 4850
# epoca 4860
# epoca 4870
# epoca 4880
# epoca 4890
# epoca 4900
# epoca 4910
# epoca 4920
# epoca 4930
# epoca 4940
# epoca 4950
# epoca 4960
# epoca 4970
# epoca 4980
# epoca 4990
# epoca 5000
# epoca 5010
# epoca 5020
# epoca 5030
# epoca 5040
# epoca 5050
# epoca 5060
# epoca 5070
# epoca 5080
# epoca 5090
# epoca 5100
# epoca 5110
# epoca 5120
# epoca 5130
# epoca 5140
# epoca 5150
# epoca 5160
# epoca 5170
# epoca 5180
# epoca 5190
# epoca 5200
# epoca 5210
# epoca 5220
# epoca 5230
# epoca 5240
# epoca 5250
# epoca 5260
# epoca 5270
# epoca 5280
# epoca 5290
# epoca 5300
# epoca 5310
# epoca 5320
# epoca 5330
# epoca 5340
# epoca 5350
# epoca 5360
# epoca 5370
# epoca 5380
# epoca 5390
# epoca 5400
# epoca 5410
# epoca 5420
# epoca 5430
# epoca 5440
# epoca 5450
# epoca 5460
# epoca 5470
# epoca 5480
# epoca 5490
# epoca 5500
# epoca 5510
# epoca 5520
# epoca 5530
# epoca 5540
# epoca 5550
# epoca 5560
# epoca 5570
# epoca 5580
# epoca 5590
# epoca 5600
# epoca 5610
# epoca 5620
# epoca 5630
# epoca 5640
# epoca 5650
# epoca 5660
# epoca 5670
# epoca 5680
# epoca 5690
# epoca 5700
# epoca 5710
# epoca 5720
# epoca 5730
# epoca 5740
# epoca 5750
# epoca 5760
# epoca 5770
# epoca 5780
# epoca 5790
# epoca 5800
# epoca 5810
# epoca 5820
# epoca 5830
# epoca 5840
# epoca 5850
# epoca 5860
# epoca 5870
# epoca 5880
# epoca 5890
# epoca 5900
# epoca 5910
# epoca 5920
# epoca 5930
# epoca 5940
# epoca 5950
# epoca 5960
# epoca 5970
# epoca 5980
# epoca 5990
# epoca 6000
# epoca 6010
# epoca 6020
# epoca 6030
# epoca 6040
# epoca 6050
# epoca 6060
# epoca 6070
# epoca 6080
# epoca 6090
# epoca 6100
# epoca 6110
# epoca 6120
# epoca 6130
# epoca 6140
# epoca 6150
# epoca 6160
# epoca 6170
# epoca 6180
# epoca 6190
# epoca 6200
# epoca 6210
# epoca 6220
# epoca 6230
# epoca 6240
# epoca 6250
# epoca 6260
# epoca 6270
# epoca 6280
# epoca 6290
# epoca 6300
# epoca 6310
# epoca 6320
# epoca 6330
# epoca 6340
# epoca 6350
# epoca 6360
# epoca 6370
# epoca 6380
# epoca 6390
# epoca 6400
# epoca 6410
# epoca 6420
# epoca 6430
# epoca 6440
# epoca 6450
# epoca 6460
# epoca 6470
# epoca 6480
# epoca 6490
# epoca 6500
# epoca 6510
# epoca 6520
# epoca 6530
# epoca 6540
# epoca 6550
# epoca 6560
# epoca 6570
# epoca 6580
# epoca 6590
# epoca 6600
# epoca 6610
# epoca 6620
# epoca 6630
# epoca 6640
# epoca 6650
# epoca 6660
# epoca 6670
# epoca 6680
# epoca 6690
# epoca 6700
# epoca 6710
# epoca 6720
# epoca 6730
# epoca 6740
# epoca 6750
# epoca 6760
# epoca 6770
# epoca 6780
# epoca 6790
# epoca 6800
# epoca 6810
# epoca 6820
# epoca 6830
# epoca 6840
# epoca 6850
# epoca 6860
# epoca 6870
# epoca 6880
# epoca 6890
# epoca 6900
# epoca 6910
# epoca 6920
# epoca 6930
# epoca 6940
# epoca 6950
# epoca 6960
# epoca 6970
# epoca 6980
# epoca 6990
# epoca 7000
# epoca 7010
# epoca 7020
# epoca 7030
# epoca 7040
# epoca 7050
# epoca 7060
# epoca 7070
# epoca 7080
# epoca 7090
# epoca 7100
# epoca 7110
# epoca 7120
# epoca 7130
# epoca 7140
# epoca 7150
# epoca 7160
# epoca 7170
# epoca 7180
# epoca 7190
# epoca 7200
# epoca 7210
# epoca 7220
# epoca 7230
# epoca 7240
# epoca 7250
# epoca 7260
# epoca 7270
# epoca 7280
# epoca 7290
# epoca 7300
# epoca 7310
# epoca 7320
# epoca 7330
# epoca 7340
# epoca 7350
# epoca 7360
# epoca 7370
# epoca 7380
# epoca 7390
# epoca 7400
# epoca 7410
# epoca 7420
# epoca 7430
# epoca 7440
# epoca 7450
# epoca 7460
# epoca 7470
# epoca 7480
# epoca 7490
# epoca 7500
# epoca 7510
# epoca 7520
# epoca 7530
# epoca 7540
# epoca 7550
# epoca 7560
# epoca 7570
# epoca 7580
# epoca 7590
# epoca 7600
# epoca 7610
# epoca 7620
# epoca 7630
# epoca 7640
# epoca 7650
# epoca 7660
# epoca 7670
# epoca 7680
# epoca 7690
# epoca 7700
# epoca 7710
# epoca 7720
# epoca 7730
# epoca 7740
# epoca 7750
# epoca 7760
# epoca 7770
# epoca 7780
# epoca 7790
# epoca 7800
# epoca 7810
# epoca 7820
# epoca 7830
# epoca 7840
# epoca 7850
# epoca 7860
# epoca 7870
# epoca 7880
# epoca 7890
# epoca 7900
# epoca 7910
# epoca 7920
# epoca 7930
# epoca 7940
# epoca 7950
# epoca 7960
# epoca 7970
# epoca 7980
# epoca 7990
# epoca 8000
# epoca 8010
# epoca 8020
# epoca 8030
# epoca 8040
# epoca 8050
# epoca 8060
# epoca 8070
# epoca 8080
# epoca 8090
# epoca 8100
# epoca 8110
# epoca 8120
# epoca 8130
# epoca 8140
# epoca 8150
# epoca 8160
# epoca 8170
# epoca 8180
# epoca 8190
# epoca 8200
# epoca 8210
# epoca 8220
# epoca 8230
# epoca 8240
# epoca 8250
# epoca 8260
# epoca 8270
# epoca 8280
# epoca 8290
# epoca 8300
# epoca 8310
# epoca 8320
# epoca 8330
# epoca 8340
# epoca 8350
# epoca 8360
# epoca 8370
# epoca 8380
# epoca 8390
# epoca 8400
# epoca 8410
# epoca 8420
# epoca 8430
# epoca 8440
# epoca 8450
# epoca 8460
# epoca 8470
# epoca 8480
# epoca 8490
# epoca 8500
# epoca 8510
# epoca 8520
# epoca 8530
# epoca 8540
# epoca 8550
# epoca 8560
# epoca 8570
# epoca 8580
# epoca 8590
# epoca 8600
# epoca 8610
# epoca 8620
# epoca 8630
# epoca 8640
# epoca 8650
# epoca 8660
# epoca 8670
# epoca 8680
# epoca 8690
# epoca 8700
# epoca 8710
# epoca 8720
# epoca 8730
# epoca 8740
# epoca 8750
# epoca 8760
# epoca 8770
# epoca 8780
# epoca 8790
# epoca 8800
# epoca 8810
# epoca 8820
# epoca 8830
# epoca 8840
# epoca 8850
# epoca 8860
# epoca 8870
# epoca 8880
# epoca 8890
# epoca 8900
# epoca 8910
# epoca 8920
# epoca 8930
# epoca 8940
# epoca 8950
# epoca 8960
# epoca 8970
# epoca 8980
# epoca 8990
# epoca 9000
# epoca 9010
# epoca 9020
# epoca 9030
# epoca 9040
# epoca 9050
# epoca 9060
# epoca 9070
# epoca 9080
# epoca 9090
# epoca 9100
# epoca 9110
# epoca 9120
# epoca 9130
# epoca 9140
# epoca 9150
# epoca 9160
# epoca 9170
# epoca 9180
# epoca 9190
# epoca 9200
# epoca 9210
# epoca 9220
# epoca 9230
# epoca 9240
# epoca 9250
# epoca 9260
# epoca 9270
# epoca 9280
# epoca 9290
# epoca 9300
# epoca 9310
# epoca 9320
# epoca 9330
# epoca 9340
# epoca 9350
# epoca 9360
# epoca 9370
# epoca 9380
# epoca 9390
# epoca 9400
# epoca 9410
# epoca 9420
# epoca 9430
# epoca 9440
# epoca 9450
# epoca 9460
# epoca 9470
# epoca 9480
# epoca 9490
# epoca 9500
# epoca 9510
# epoca 9520
# epoca 9530
# epoca 9540
# epoca 9550
# epoca 9560
# epoca 9570
# epoca 9580
# epoca 9590
# epoca 9600
# epoca 9610
# epoca 9620
# epoca 9630
# epoca 9640
# epoca 9650
# epoca 9660
# epoca 9670
# epoca 9680
# epoca 9690
# epoca 9700
# epoca 9710
# epoca 9720
# epoca 9730
# epoca 9740
# epoca 9750
# epoca 9760
# epoca 9770
# epoca 9780
# epoca 9790
# epoca 9800
# epoca 9810
# epoca 9820
# epoca 9830
# epoca 9840
# epoca 9850
# epoca 9860
# epoca 9870
# epoca 9880
# epoca 9890
# epoca 9900
# epoca 9910
# epoca 9920
# epoca 9930
# epoca 9940
# epoca 9950
# epoca 9960
# epoca 9970
# epoca 9980
# epoca 9990

# %%
#plota o erro epoca a epoca
plt.figure(figsize=(4, 4))
plt.plot(range(contador_epocas), erro_epocas[:contador_epocas])
plt.title('Gráfico de convergencia do erro')
plt.xlabel("epoca")
plt.ylabel("erro")
plt.grid(True)
plt.show()
